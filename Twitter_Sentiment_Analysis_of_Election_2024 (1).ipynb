# %% [markdown]
# # Crawl Data Twitter
# The crawling process was done using Tweet-Harvest.

# %%
#@title Twitter Auth Token

twitter_auth_token = 'afc04dbb0616e9d04ef90a3570ca2bb2a13ce07a'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# Crawl Data

filename = 'scraping_data.csv'
search_keyword = 'anies ganjar prabowo lang:id'
limit = 1000

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 846ms
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Fri Jan 19 01:14:44 +0000 2024  1748151975274049837
# 1    Fri Jan 19 01:14:29 +0000 2024  1748151912946668003
# 2    Fri Jan 19 01:13:47 +0000 2024  1748151735343051085
# 3    Fri Jan 19 01:13:35 +0000 2024  1748151685439234547
# 4    Fri Jan 19 01:13:31 +0000 2024  1748151666363228598
# ..                              ...                  ...
# 168  Thu Jan 18 11:29:23 +0000 2024  1747944270487839175
# 169  Thu Jan 18 11:25:47 +0000 2024  1747943363519947163
# 170  Thu Jan 18 11:25:23 +0000 2024  1747943261678039121
# 171  Thu Jan 18 11:23:19 +0000 2024  1747942740422439401
# 172  Thu Jan 18 11:18:31 +0000 2024  1747941534069064156
#
#                                              full_text  quote_count  \
# 0    Selama jokowi dan lingkarannya masih berkuasa ...            0
# 1    @GiloMoh @bengkeldodo @Ndons_Back @AndreasSolu...            0
# 2    Golput = mendukung Prabowo menang di Pilpres 2...            0
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 173.

# %%
# For analysis and cleaning
import pandas as pd
import numpy as np
# for visaluatztion
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/tweets-data/scraping_data.csv',delimiter=";")
df.head()
# Out:
#                        created_at               id_str  \
# 0  Fri Jan 19 01:14:44 +0000 2024  1748151975274049837
# 1  Fri Jan 19 01:14:29 +0000 2024  1748151912946668003
# 2  Fri Jan 19 01:13:47 +0000 2024  1748151735343051085
# 3  Fri Jan 19 01:13:35 +0000 2024  1748151685439234547
# 4  Fri Jan 19 01:13:31 +0000 2024  1748151666363228598
#
#                                            full_text  quote_count  \
# 0  Selama jokowi dan lingkarannya masih berkuasa ...            0
# 1  @GiloMoh @bengkeldodo @Ndons_Back @AndreasSolu...            0
# 2  Golput = mendukung Prabowo menang di Pilpres 2...            0
# 3  @JhontalJk @herculep638 Golput = mendukung Pra...            0
# 4  @FitrahDharul @bengkeldodo @Ndons_Back @Andrea...            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in  1694711483811426304
# 1            1              0               0   in  1694711483811426304
# ...

# %%
df.shape
# Out:
# (173, 12)

# %%
df.isnull().sum()
# Out:
# created_at             0
# id_str                 0
# full_text              0
# quote_count            0
# reply_count            0
# retweet_count          0
# favorite_count         0
# lang                   0
# user_id_str            0
# conversation_id_str    0
# username               0
# tweet_url              0
# dtype: int64

# %%
df.dtypes
# Out:
# created_at             object
# id_str                  int64
# full_text              object
# quote_count             int64
# reply_count             int64
# retweet_count           int64
# favorite_count          int64
# lang                   object
# user_id_str             int64
# conversation_id_str     int64
# username               object
# tweet_url              object
# dtype: object

# %%
df['Sentiment'].value_counts().nlargest(10).plot(kind='bar')
plt.title('Top 10 Sentiments based on Text')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sentiment'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #Twitter Sentiment Analysis of Election 2024

# %% [markdown]
# ###Import Package

# %%
#import library
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###Load Data

# %%
df = pd.read_csv("/content/tweets-data/scraping_data.csv", delimiter=";")
df.head()

# %%
df = df[['full_text', 'username', 'created_at']]
df

# %% [markdown]
# ## 1. Cleaning Data

# %%
df.shape

# %%
df = df.drop_duplicates(subset = ['full_text'])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# created_at             0
# id_str                 0
# full_text              0
# quote_count            0
# reply_count            0
# retweet_count          0
# favorite_count         0
# lang                   0
# user_id_str            0
# conversation_id_str    0
# username               0
# tweet_url              0
# dtype: int64

# %%
df.shape
# Out:
# (173, 12)

# %%
def clean_twitter_text(text):
  text = re.sub(r'@[A-Za-z0-9_]+', ' ', text)
  text = re.sub(r'#\w+', ' ', text)
  text = re.sub(r'RT[\s]', ' ', text)
  text = re.sub(r'https?://\S+', ' ', text)
  text = re.sub(r'[^A-Za-z0-9]', ' ', text)
  text = re.sub(r'\s+', ' ', text).strip()

  return text

df['full_text'] = df['full_text'].apply(clean_twitter_text)

# %%
df['full_text'] = df['full_text'].astype(str).str.lower()

# %%
df
# Out:
#                          created_at               id_str  \
# 0    Fri Jan 19 01:14:44 +0000 2024  1748151975274049837
# 1    Fri Jan 19 01:14:29 +0000 2024  1748151912946668003
# 2    Fri Jan 19 01:13:47 +0000 2024  1748151735343051085
# 3    Fri Jan 19 01:13:35 +0000 2024  1748151685439234547
# 4    Fri Jan 19 01:13:31 +0000 2024  1748151666363228598
# ..                              ...                  ...
# 168  Thu Jan 18 11:29:23 +0000 2024  1747944270487839175
# 169  Thu Jan 18 11:25:47 +0000 2024  1747943363519947163
# 170  Thu Jan 18 11:25:23 +0000 2024  1747943261678039121
# 171  Thu Jan 18 11:23:19 +0000 2024  1747942740422439401
# 172  Thu Jan 18 11:18:31 +0000 2024  1747941534069064156
#
#                                              full_text  quote_count  \
# 0    selama jokowi dan lingkarannya masih berkuasa ...            0
# 1    selama jokowi dan lingkarannya masih berkuasa ...            0
# 2    golput mendukung prabowo menang di pilpres 202...            0
# ...

# %% [markdown]
# ##2. Preprocessing

# %%
#normalisasi
norm = {"yg" : "yang", "nggak":"tidak", "g":"tidak", "ga":"tidak"}

def normalisasi(str_text):
  for i in norm:
    str_text = str_text.replace(i, norm[i])
  return str_text

df['full_text'] = df['full_text'].apply(lambda x: normalisasi(x))
df
# Out:
#                          created_at               id_str  \
# 0    Fri Jan 19 01:14:44 +0000 2024  1748151975274049837
# 1    Fri Jan 19 01:14:29 +0000 2024  1748151912946668003
# 2    Fri Jan 19 01:13:47 +0000 2024  1748151735343051085
# 3    Fri Jan 19 01:13:35 +0000 2024  1748151685439234547
# 4    Fri Jan 19 01:13:31 +0000 2024  1748151666363228598
# ..                              ...                  ...
# 168  Thu Jan 18 11:29:23 +0000 2024  1747944270487839175
# 169  Thu Jan 18 11:25:47 +0000 2024  1747943363519947163
# 170  Thu Jan 18 11:25:23 +0000 2024  1747943261678039121
# 171  Thu Jan 18 11:23:19 +0000 2024  1747942740422439401
# 172  Thu Jan 18 11:18:31 +0000 2024  1747941534069064156
#
#                                              full_text  quote_count  \
# 0    selama jokowi dan lintidakkarannya masih berku...            0
# 1    selama jokowi dan lintidakkarannya masih berku...            0
# 2    tidakolput mendukuntidak prabowo menantidak di...            0
# ...

# %%
# !pip install Sastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 1.9 MB/s eta 0:00:00
# ...

# %%
#Stopwords
import Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
more_stop_words = ['tidak']

stop_words = StopWordRemoverFactory().get_stop_words()
stop_words.extend(more_stop_words)

new_array = ArrayDictionary(stop_words)
stop_words_remover_new = StopWordRemover(new_array)

def stopword(str_text):
  str_text = stop_words_remover_new.remove(str_text)
  return str_text

df['full_text'] = df['full_text'].apply(lambda x: stopword(x))
df.head()
# Out:
#                        created_at               id_str  \
# 0  Fri Jan 19 01:14:44 +0000 2024  1748151975274049837
# 1  Fri Jan 19 01:14:29 +0000 2024  1748151912946668003
# 2  Fri Jan 19 01:13:47 +0000 2024  1748151735343051085
# 3  Fri Jan 19 01:13:35 +0000 2024  1748151685439234547
# 4  Fri Jan 19 01:13:31 +0000 2024  1748151666363228598
#
#                                            full_text  quote_count  \
# 0  selama jokowi lintidakkarannya berkuasa politi...            0
# 1  selama jokowi lintidakkarannya berkuasa politi...            0
# 2  tidakolput mendukuntidak prabowo menantidak pi...            0
# 3  tidakolput mendukuntidak prabowo menantidak pi...            0
# 4  selama jokowi lintidakkarannya berkuasa politi...            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in  1694711483811426304
# 1            1              0               0   in  1694711483811426304
# ...

# %%
#Steming
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def stemming(text_cleaning):
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()
  do = []
  for w in text_cleaning:
    dt = stemmer.stem(w)
    do.append(dt)
  d_clean = []
  d_clean = "".join(do)
  print(d_clean)
  return d_clean

tokenized = df['full_text'].apply(stemming)

tokenized.to_csv("/content/sentiment_anlysis.csv", index = False)
data = pd.read_csv("/content/sentiment_anlysis.csv", encoding = 'latin1')
# Out:
# selamajokowilintidakkarannyaberkuasapolitisiyantidaktersanderahukumterustersenyumkarenanyapilpres2024yantidakkalahkanbukanprabowotidakanjarkitakalahkanjokowidentidakancarapilihno1aminaniesmuhaimin
# selamajokowilintidakkarannyaberkuasapolitisiyantidaktersanderahukumterustersenyumkarenanyapilpres2024yantidakkalahkanbukanprabowotidakanjarkitakalahkanjokowidentidakancarapilihno1aminaniesmuhaimin
# tidakolputmendukuntidakprabowomenantidakpilpres2024jadijantidakantidakolputpilihaniestidakanjarasalbukanprabowo
# tidakolputmendukuntidakprabowomenantidakpilpres2024jadijantidakantidakolputpilihaniestidakanjarasalbukanprabowo
# selamajokowilintidakkarannyaberkuasapolitisiyantidaktersanderahukumterustersenyumkarenanyapilpres2024yantidakkalahkanbukanprabowotidakanjarkitakalahkanjokowidentidakancarapilihno1aminaniesmuhaimin
# ...

# %%
#Tokenize
tokenized = df['full_text'].apply(lambda x:x.split())
tokenized.to_csv("/content/sentiment_anlysis.csv", index = False)
pd.read_csv("/content/sentiment_anlysis.csv")
# Out:
#                                              full_text
# 0    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 1    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 2    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 3    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 4    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# ..                                                 ...
# 168  ['2', 'hasil', 'potret', 'kondisi', 'ini', 'de...
# 169  ['makanya', 'serintidak', 'berdoa', 'terus', '...
# 170  ['elu', 'pendukuntidak', 'tidakanjar', 'tidakw...
# 171  ['tapii', 'tidakue', 'rasa', 'research', 'lati...
# 172  ['feed', 'tidakw', 'isinya', 'pemuja', 'anies'...
#
# [173 rows x 1 columns]

# %% [markdown]
# ##3. Translate

# %%
# !pip install translate

# %%
data = pd.read_csv("/content/sentiment_anlysis.csv")
data.head()
# Out:
#                                            full_text
# 0  ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 1  ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 2  ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 3  ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 4  ['selama', 'jokowi', 'lintidakkarannya', 'berk...

# %%
from translate import Translator

def convert_eng(tweet):
  translator = Translator(to_lang = "en", from_lang = "id")
  translation = translator.translate(tweet)
  return translation

data['tweet_english'] = data['full_text'].apply(convert_eng)
data.to_csv("translation.csv")

# %% [markdown]
# ##4. Labeling

# %%
data = pd.read_csv('/content/translation.csv', index_col = 0)
data
# Out:
#                                              full_text  \
# 0    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 1    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 2    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 3    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 4    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# ..                                                 ...
# 168  ['2', 'hasil', 'potret', 'kondisi', 'ini', 'de...
# 169  ['makanya', 'serintidak', 'berdoa', 'terus', '...
# 170  ['elu', 'pendukuntidak', 'tidakanjar', 'tidakw...
# 171  ['tapii', 'tidakue', 'rasa', 'research', 'lati...
# 172  ['feed', 'tidakw', 'isinya', 'pemuja', 'anies'...
#
#                                          tweet_english
# 0    ['as long as', 'jokowi', 'lintidakkarannya', '...
# 1    ['as long as', 'jokowi', 'lintidakkarannya', '...
# 2    ['takolput', 'mendukuntidak', 'prabowo', 'mena...
# 3    ['takolput', 'mendukuntidak', 'prabowo', 'mena...
# ...

# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install wordcloud
# !pip install nltk

# %%
import preprocessor as p
from textblob import TextBlob
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data_tweet = list(data['tweet_english'])
polaritas = 0

status = []
total_positif = total_negatif = total_netral = total = 0

for i, tweet in enumerate(data_tweet):
  analysis = TextBlob(tweet)
  polaritas += analysis.polarity

  if analysis.sentiment.polarity > 0.0:
    total_positif += 1
    status.append('Positif')
  elif analysis.sentiment.polarity == 0.0:
    total_netral += 1
    status.append('Netral')
  else:
    total_negatif += 1
    status.append('Negatif')

  total += 1

print(f"Hasil analisis data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}")
print(f"\nTotal Data: {total}")
# Out:
# Hasil analisis data:
# Positif = 126
# Netral = 31
# Negatif = 16
#
# Total Data: 173

# %%
data['klasifikasi'] = status
data
# Out:
#                                              full_text  \
# 0    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 1    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 2    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 3    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 4    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# ..                                                 ...
# 168  ['2', 'hasil', 'potret', 'kondisi', 'ini', 'de...
# 169  ['makanya', 'serintidak', 'berdoa', 'terus', '...
# 170  ['elu', 'pendukuntidak', 'tidakanjar', 'tidakw...
# 171  ['tapii', 'tidakue', 'rasa', 'research', 'lati...
# 172  ['feed', 'tidakw', 'isinya', 'pemuja', 'anies'...
#
#                                          tweet_english klasifikasi
# 0    ['as long as', 'jokowi', 'lintidakkarannya', '...     Positif
# 1    ['as long as', 'jokowi', 'lintidakkarannya', '...     Positif
# 2    ['takolput', 'mendukuntidak', 'prabowo', 'mena...      Netral
# ...

# %% [markdown]
# ##5. Visualisasi

# %%
from wordcloud import WordCloud, STOPWORDS

def plot_cloud(wordcloud):
  plt.figure(figsize = (10, 8))
  plt.imshow(wordcloud, interpolation = 'bilinear')
  plt.axis('off')
  plt.show()

all_words = ''.join([tweets for tweets in data['full_text']])

wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    random_state = 3,
    background_color = 'black',
    colormap = 'Blues_r',
    collocations = False,
    stopwords=STOPWORDS).generate(all_words)

plot_cloud(wordcloud)

# %%
import seaborn as sns

sns.set_theme()

labels = ['Positif', 'Negatif', 'Netral']
counts = [total_positif, total_negatif, total_netral]

def show_bar_chart(labels, counts, title):
  fig, ax = plt.subplots(figsize = (8, 6))
  bars = ax.bar(labels, counts, color = ['#2394f7', '#f72323', '#fac343'])

  for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax.annotate(f'{count}', xy = (bar.get_x() + bar.get_width()/2, height),
                xytext=(0, 3),
                textcoords = "offset points",
                ha = 'center', va = 'bottom')
  ax.grid(axis = 'y', linestyle = '--', alpha = 0.7)

  ax.set_xlabel('Sentimen')
  ax.set_ylabel('Jumlah')
  ax.set_title(title)

  plt.show()

show_bar_chart(labels, counts, "Distribusi Sentimen Calon Presiden 2024")

# %% [markdown]
# ##6. Klasifikasi Sentimen

# %%
data
# Out:
#                                              full_text  \
# 0    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 1    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 2    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 3    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 4    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# ..                                                 ...
# 168  ['2', 'hasil', 'potret', 'kondisi', 'ini', 'de...
# 169  ['makanya', 'serintidak', 'berdoa', 'terus', '...
# 170  ['elu', 'pendukuntidak', 'tidakanjar', 'tidakw...
# 171  ['tapii', 'tidakue', 'rasa', 'research', 'lati...
# 172  ['feed', 'tidakw', 'isinya', 'pemuja', 'anies'...
#
#                                          tweet_english klasifikasi
# 0    ['as long as', 'jokowi', 'lintidakkarannya', '...     Positif
# 1    ['as long as', 'jokowi', 'lintidakkarannya', '...     Positif
# 2    ['takolput', 'mendukuntidak', 'prabowo', 'mena...      Netral
# ...

# %%
dataset = data.drop(['full_text'], axis = 1, inplace = False)
dataset = [tuple(x) for x in dataset.to_records(index = False)]

# %%
import random

set_positif = []
set_negatif = []
set_netral = []

for n in dataset:
  if(n[1] == 'Positif'):
    set_positif.append(n)
  elif(n[1] == 'Negatif'):
    set_negatif.append(n)
  else:
    set_netral.append(n)

set_positif = random.sample(set_positif, k = int(len(set_positif)/2))
set_negatif = random.sample(set_negatif, k = int(len(set_negatif)/2))
set_netral = random.sample(set_netral, k = int(len(set_netral)/2))

train = set_positif + set_negatif + set_netral

train_set = []

for n in train:
  train_set.append(n)

# %%
from textblob.classifiers import NaiveBayesClassifier
cl = NaiveBayesClassifier(train_set)
print("Akurasi Test: ", cl.accuracy(dataset))
# Out:
# Akurasi Test:  0.7803468208092486

# %%
#Labeling

data_tweet = list(data['tweet_english'])
polaritas = 0

status = []
total_positif = total_negatif = total_netral = total = 0

for i, tweet in enumerate(data_tweet):
  analysis = TextBlob(tweet, classifier = cl)

  if analysis.classify() == 'Positif':
    total_positif +=1
  elif analysis.classify() == 'Netral':
    total_netral += 1
  else:
    total_negatif += 1

  status.append(analysis.classify())
  total += 1
print(f'\nHasil Analisis Data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print(f'\nTotal Data: {total}')
# Out:
# Hasil Analisis Data:
# Positif = 105
# Netral = 55
# Negatif = 13
#
# Total Data: 173

# %%
status = pd.DataFrame({"Klasifikasi Bayes": status})
data['klasifikasi_bayes'] = status

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

labels = ['Positif', 'Negatif', 'Netral']
counts = [total_positif, total_negatif, total_netral]

def show_bar_chart(labels, counts, title):
  fig, ax = plt.subplots(figsize = (8, 6))
  bars = ax.bar(labels, counts, color = ['#2394f7', '#f72323', '#fac343'])

  #Add presentase
  for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax.annotate(f'{count}', xy = (bar.get_x() + bar.get_width()/2, height),
                xytext = (0,3),
                textcoords = "offset points",
                ha = 'center', va = 'bottom')

    #Add grid
    ax.grid(axis = 'y', linestyle = '--', alpha = 0.7)

    #Add title
    ax.set_xlabel('Sentiment')
    ax.set_ylabel('Total')
    ax.set_title(title)

    plt.show()
show_bar_chart(labels, counts, "Sentiment Distribution of President Candidates")

# %%
data
# Out:
#                                              full_text  \
# 0    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 1    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# 2    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 3    ['tidakolput', 'mendukuntidak', 'prabowo', 'me...
# 4    ['selama', 'jokowi', 'lintidakkarannya', 'berk...
# ..                                                 ...
# 168  ['2', 'hasil', 'potret', 'kondisi', 'ini', 'de...
# 169  ['makanya', 'serintidak', 'berdoa', 'terus', '...
# 170  ['elu', 'pendukuntidak', 'tidakanjar', 'tidakw...
# 171  ['tapii', 'tidakue', 'rasa', 'research', 'lati...
# 172  ['feed', 'tidakw', 'isinya', 'pemuja', 'anies'...
#
#                                          tweet_english klasifikasi  \
# 0    ['as long as', 'jokowi', 'lintidakkarannya', '...     Positif
# 1    ['as long as', 'jokowi', 'lintidakkarannya', '...     Positif
# 2    ['takolput', 'mendukuntidak', 'prabowo', 'mena...      Netral
# ...

# %%
data_eval = [tuple(x) for x in data.to_records(index = False)]

for n in data_eval:
  if len(n) >=4:
    if n[2] != n[3]:
      print(f'Text: {n[0]}\nClassifier: {n[2]}\nClassifier Bayes: {n[3]}\n')
    else:
      print("Tuple tidak memiliki cukup elemen")
# Out:
# Text: ['selama', 'jokowi', 'lintidakkarannya', 'berkuasa', 'politisi', 'yantidak', 'tersandera', 'hukum', 'terus', 'tersenyum', 'karenanya', 'pilpres', '2024', 'yantidak', 'kalahkan', 'bukan', 'prabowo', 'tidakanjar', 'kita', 'kalahkan', 'jokowi', 'dentidakan', 'cara', 'pilih', 'no', '1', 'amin', 'anies', 'muhaimin']
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text: ['selama', 'jokowi', 'lintidakkarannya', 'berkuasa', 'politisi', 'yantidak', 'tersandera', 'hukum', 'terus', 'tersenyum', 'karenanya', 'pilpres', '2024', 'yantidak', 'kalahkan', 'bukan', 'prabowo', 'tidakanjar', 'kita', 'kalahkan', 'jokowi', 'dentidakan', 'cara', 'pilih', 'no', '1', 'amin', 'anies', 'muhaimin']
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Tuple tidak memiliki cukup elemen
# Tuple tidak memiliki cukup elemen
# ...

# %% [markdown]
# ###Analysis
